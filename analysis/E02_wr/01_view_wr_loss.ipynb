# %% [markdown]
# # ON A 1K EPOCHS

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))
import os

if os.path.basename(os.getcwd()) == "tests":
    os.chdir("..")

# %%
import pickle

file = "E02_win_rate.pkl"

with open(file, "rb") as f:
    evals = pickle.load(f)
evals
# Out:
# {'epochs_results': [{'bot_good': {'wins': 15, 'losses': 15, 'draws': 0},
#    'bot_random': {'wins': 16, 'losses': 14, 'draws': 0},
#    'bot_Michael2': {'wins': 12, 'losses': 18, 'draws': 0}},
#   {'bot_good': {'wins': 13, 'losses': 17, 'draws': 0},
#    'bot_random': {'wins': 14, 'losses': 16, 'draws': 0},
#    'bot_Michael2': {'wins': 11, 'losses': 19, 'draws': 0}},
#   {'bot_good': {'wins': 13, 'losses': 17, 'draws': 0},
#    'bot_random': {'wins': 16, 'losses': 14, 'draws': 0},
#    'bot_Michael2': {'wins': 17, 'losses': 13, 'draws': 0}},
#   {'bot_good': {'wins': 12, 'losses': 18, 'draws': 0},
#    'bot_random': {'wins': 14, 'losses': 16, 'draws': 0},
#    'bot_Michael2': {'wins': 9, 'losses': 21, 'draws': 0}},
#   {'bot_good': {'wins': 11, 'losses': 19, 'draws': 0},
#    'bot_random': {'wins': 14, 'losses': 16, 'draws': 0},
#    'bot_Michael2': {'wins': 15, 'losses': 15, 'draws': 0}},
#   {'bot_good': {'wins': 11, 'losses': 19, 'draws': 0},
# ...

# %%
evals.keys()
# Out:
# dict_keys(['epochs_results', 'loss_values', 'win_rate'])

# %%
import plotly.graph_objs as go

win_rate = evals["win_rate"]

fig = go.Figure()
for bot, rates in win_rate.items():
    fig.add_trace(go.Scatter(y=rates, mode="lines", name=bot))

fig.update_layout(
    title="Win Rate per Epoch",
    xaxis_title="Epoch",
    yaxis_title="Win Rate",
    legend_title="Bot",
)
fig.show()

# %%
loss_epoch = [
    evals["loss_values"]["loss_values"][j] for j in evals["loss_values"]["epoch_values"]
]

# %%
import plotly.graph_objs as go

win_rate = evals["win_rate"]
w_r_smoothed = {}
for bot, rates in win_rate.items():
    smoothed = []
    for i in range(len(rates)):
        window = rates[max(0, i - 5) : min(len(rates), i + 6)]
        smoothed.append(sum(window) / len(window))
    w_r_smoothed[bot] = smoothed

fig = go.Figure()
fig.add_trace(
    go.Scatter(
        y=win_rate["bot_good"],
        mode="markers",
        name="bot_good",
        marker=dict(color="blue", size=3),
    )
)
fig.add_trace(
    go.Scatter(
        y=w_r_smoothed["bot_good"],
        mode="lines",
        name="good_smoothed",
        line=dict(width=3, color="blue"),
    )
)
fig.add_trace(
    go.Scatter(
        y=loss_epoch,
        mode="lines",
        name="Loss",
        # line=dict(width=3, color="blue"),
    )
)

fig.add_vline(x=27, line_width=2, line_dash="dash", line_color="red")
fig.update_layout(
    title="Win Rate per Epoch",
    xaxis_title="Epoch",
    yaxis_title="Win Rate",
    xaxis=dict(range=[0, 200]),  # Set your desired limits here
)
fig.show()
