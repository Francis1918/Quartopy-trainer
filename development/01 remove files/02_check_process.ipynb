# %%
from quartopy import play_games, BotAI, Board

# %%
# %load_ext autoreload
import sys
from pathlib import Path

sys.path.append(r"C:/Users/Laboratorio IA/Desktop/githubs/hierarchical-SAE/")

# %%
from bot.CNN_bot import Quarto_bot
from models.CNN1 import QuartoCNN


policy_net = QuartoCNN()

number_of_matches: int = 1000
p1 = Quarto_bot(model=policy_net, deterministic=False)
p2 = Quarto_bot(model=policy_net, deterministic=True)  # self play

results, win_rate = play_games(
    matches=number_of_matches,
    player1=p1,
    player2=p2,
    delay=0,
    verbose=False,
    # verbose=True,
    PROGRESS_MESSAGE="Testing bots...",
    save_match=False,
)
win_rate
# Out:
# Testing bots...:   0%|          | 0/1000 [00:00<?, ?it/s]
# defaultdict(<function quartopy.game.play.play_games.<locals>.<lambda>()>,
#             {'Player 2': 522, 'Player 1': 460, 'Tie': 18})

# %%
win_rate
# Out:
# defaultdict(<function quartopy.game.play.play_games.<locals>.<lambda>()>,
#             {'Player 2': 522, 'Player 1': 460, 'Tie': 18})

# %%
results[0].keys()
# Out:
# dict_keys(['move_history', 'Player 1', 'Player 2', 'winner_pos'])

# %%
results[0]["winner_pos"]
# Out:
# 'Player 2'

# %%
results[0]["move_history"]
# Out:
# [{'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, CIRCLE, WITH_HOLE',
#   'piece_index': 5,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 1),
#   'position_index': 5,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 0,
#   'attempt': 2},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (0, 0),
#   'position_index': 0,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, SQUARE, WITHOUT_HOLE',
#   'piece_index': 14,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 1),
#   'position_index': 13,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, SQUARE, WITH_HOLE',
#   'piece_index': 7,
#   'attempt': 3},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (0, 2),
#   'position_index': 2,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITH_HOLE',
#   'piece_index': 13,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (0, 3),
#   'position_index': 3,
#   'attempt': 3,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, CIRCLE, WITH_HOLE',
#   'piece_index': 9,
#   'attempt': 3},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (1, 0),
#   'position_index': 4,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, SQUARE, WITH_HOLE',
#   'piece_index': 15,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 3),
#   'position_index': 15,
#   'attempt': 5,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 8,
#   'attempt': 7},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (1, 3),
#   'position_index': 7,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 3,
#   'attempt': 5},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 2),
#   'position_index': 6,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, SQUARE, WITHOUT_HOLE',
#   'piece_index': 6,
#   'attempt': 8},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 1),
#   'position_index': 9,
#   'attempt': 4,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 11,
#   'attempt': 4},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 2),
#   'position_index': 14,
#   'attempt': 8,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 12,
#   'attempt': 10},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 0),
#   'position_index': 8,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, SQUARE, WITHOUT_HOLE',
#   'piece_index': 2,
#   'attempt': 4},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 0),
#   'position_index': 12,
#   'attempt': 9,
#   'board': ''}]

# %%
results[0]["Player 1"]
# Out:
# 'CNN_bot|QuartoCNN1'

# %%
m_h = results[0]["move_history"]
m_h
# Out:
# [{'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, CIRCLE, WITH_HOLE',
#   'piece_index': 5,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 1),
#   'position_index': 5,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 0,
#   'attempt': 2},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (0, 0),
#   'position_index': 0,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, SQUARE, WITHOUT_HOLE',
#   'piece_index': 14,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 1),
#   'position_index': 13,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, SQUARE, WITH_HOLE',
#   'piece_index': 7,
#   'attempt': 3},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (0, 2),
#   'position_index': 2,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITH_HOLE',
#   'piece_index': 13,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (0, 3),
#   'position_index': 3,
#   'attempt': 3,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, CIRCLE, WITH_HOLE',
#   'piece_index': 9,
#   'attempt': 3},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (1, 0),
#   'position_index': 4,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, SQUARE, WITH_HOLE',
#   'piece_index': 15,
#   'attempt': 1},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 3),
#   'position_index': 15,
#   'attempt': 5,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 8,
#   'attempt': 7},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (1, 3),
#   'position_index': 7,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 3,
#   'attempt': 5},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 2),
#   'position_index': 6,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, SQUARE, WITHOUT_HOLE',
#   'piece_index': 6,
#   'attempt': 8},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 1),
#   'position_index': 9,
#   'attempt': 4,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 11,
#   'attempt': 4},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 2),
#   'position_index': 14,
#   'attempt': 8,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 12,
#   'attempt': 10},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 0),
#   'position_index': 8,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, SQUARE, WITHOUT_HOLE',
#   'piece_index': 2,
#   'attempt': 4},
#  {'player_name': 'CNN_bot|QuartoCNN1',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (3, 0),
#   'position_index': 12,
#   'attempt': 9,
#   'board': ''}]

# %%
m_h[0]
# Out:
# {'player_name': 'CNN_bot|QuartoCNN1',
#  'player_pos': 'Player 1',
#  'action': 'selected',
#  'piece': 'LITTLE, WHITE, CIRCLE, WITH_HOLE',
#  'piece_index': 5,
#  'attempt': 1}

# %%
m_h[1]
# Out:
# {'player_name': 'CNN_bot|QuartoCNN1',
#  'player_pos': 'Player 2',
#  'action': 'placed',
#  'position': (1, 1),
#  'position_index': 5,
#  'attempt': 1,
#  'board': ''}

# %%
m_h[2]
# Out:
# {'player_name': 'CNN_bot|QuartoCNN1',
#  'player_pos': 'Player 2',
#  'action': 'selected',
#  'piece': 'LITTLE, BLACK, CIRCLE, WITHOUT_HOLE',
#  'piece_index': 0,
#  'attempt': 2}

# %%
m_h[3]
# Out:
# {'player_name': 'CNN_bot|QuartoCNN1',
#  'player_pos': 'Player 1',
#  'action': 'placed',
#  'position': (0, 0),
#  'position_index': 0,
#  'attempt': 1,
#  'board': ''}

# %%
m_h[4]
# Out:
# {'player_name': 'CNN_bot|QuartoCNN1',
#  'player_pos': 'Player 1',
#  'action': 'selected',
#  'piece': 'TALL, WHITE, SQUARE, WITHOUT_HOLE',
#  'piece_index': 14,
#  'attempt': 1}
