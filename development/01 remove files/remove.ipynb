# %%
from quartopy import play_games, BotAI, Board

# %%
# %load_ext autoreload
import sys
from pathlib import Path

sys.path.append(r"C:/Users/Laboratorio IA/Desktop/githubs/hierarchical-SAE/")

# %%
from bot.CNN_bot import Quarto_bot
from models.CNN1 import QuartoCNN


policy_net = QuartoCNN()

number_of_matches: int = 10
p1 = Quarto_bot(model=policy_net)
p2 = Quarto_bot(model=policy_net)  # self play

results, win_rate = play_games(
    matches=number_of_matches,
    player1=p1,
    player2=p2,
    delay=0,
    verbose=False,
    PROGRESS_MESSAGE="Testing bots...",
    save_match=False,
)
# Out:
# Testing bots...:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
win_rate
# Out:
# defaultdict(<function quartopy.game.play.play_games.<locals>.<lambda>()>,
#             {'Player 2': 10})

# %%
results[0].keys()
# Out:
# dict_keys(['move_history', 'Player 1', 'Player 2', 'winner_pos'])

# %%
results[0]["move_history"]
# Out:
# [{'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 4,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 3),
#   'position_index': 7,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, CIRCLE, WITH_HOLE',
#   'piece_index': 9,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 3),
#   'position_index': 11,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, SQUARE, WITHOUT_HOLE',
#   'piece_index': 14,
#   'attempt': 3,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 1),
#   'position_index': 5,
#   'attempt': 3,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, SQUARE, WITHOUT_HOLE',
#   'piece_index': 10,
#   'attempt': 4,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 1),
#   'position_index': 9,
#   'attempt': 4,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 12,
#   'attempt': 5,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 0),
#   'position_index': 4,
#   'attempt': 5,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 11,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (3, 2),
#   'position_index': 14,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 3,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (0, 3),
#   'position_index': 3,
#   'attempt': 7,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, SQUARE, WITH_HOLE',
#   'piece_index': 7,
#   'attempt': 8,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (3, 3),
#   'position_index': 15,
#   'attempt': 8,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITH_HOLE',
#   'piece_index': 13,
#   'attempt': 9,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 2),
#   'position_index': 6,
#   'attempt': 9,
#   'board': ''}]

# %%
results[0]["Player 1"]
# Out:
# 'CNN_bot|random_weights'

# %%
m_h = results[0]["move_history"]
m_h
# Out:
# [{'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 4,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 3),
#   'position_index': 7,
#   'attempt': 1,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, CIRCLE, WITH_HOLE',
#   'piece_index': 9,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 3),
#   'position_index': 11,
#   'attempt': 2,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, SQUARE, WITHOUT_HOLE',
#   'piece_index': 14,
#   'attempt': 3,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 1),
#   'position_index': 5,
#   'attempt': 3,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, SQUARE, WITHOUT_HOLE',
#   'piece_index': 10,
#   'attempt': 4,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (2, 1),
#   'position_index': 9,
#   'attempt': 4,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITHOUT_HOLE',
#   'piece_index': 12,
#   'attempt': 5,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 0),
#   'position_index': 4,
#   'attempt': 5,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'TALL, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 11,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (3, 2),
#   'position_index': 14,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'LITTLE, BLACK, SQUARE, WITH_HOLE',
#   'piece_index': 3,
#   'attempt': 6,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (0, 3),
#   'position_index': 3,
#   'attempt': 7,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'selected',
#   'piece': 'LITTLE, WHITE, SQUARE, WITH_HOLE',
#   'piece_index': 7,
#   'attempt': 8,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'placed',
#   'position': (3, 3),
#   'position_index': 15,
#   'attempt': 8,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 1',
#   'action': 'selected',
#   'piece': 'TALL, WHITE, CIRCLE, WITH_HOLE',
#   'piece_index': 13,
#   'attempt': 9,
#   'board': ''},
#  {'player_name': 'CNN_bot|random_weights',
#   'player_pos': 'Player 2',
#   'action': 'placed',
#   'position': (1, 2),
#   'position_index': 6,
#   'attempt': 9,
#   'board': ''}]

# %%
m_h[0]
# Out:
# {'player_name': 'CNN_bot|random_weights',
#  'player_pos': 'Player 1',
#  'action': 'selected',
#  'piece': 'LITTLE, WHITE, CIRCLE, WITHOUT_HOLE',
#  'piece_index': 4,
#  'attempt': 1,
#  'board': ''}

# %%
m_h[1]
# Out:
# {'player_name': 'CNN_bot|random_weights',
#  'player_pos': 'Player 2',
#  'action': 'placed',
#  'position': (1, 3),
#  'position_index': 7,
#  'attempt': 1,
#  'board': ''}

# %%
m_h[2]
# Out:
# {'player_name': 'CNN_bot|random_weights',
#  'player_pos': 'Player 2',
#  'action': 'selected',
#  'piece': 'TALL, BLACK, CIRCLE, WITH_HOLE',
#  'piece_index': 9,
#  'attempt': 2,
#  'board': ''}

# %%
m_h[3]
# Out:
# {'player_name': 'CNN_bot|random_weights',
#  'player_pos': 'Player 1',
#  'action': 'placed',
#  'position': (2, 3),
#  'position_index': 11,
#  'attempt': 2,
#  'board': ''}

# %%
m_h[4]
# Out:
# {'player_name': 'CNN_bot|random_weights',
#  'player_pos': 'Player 1',
#  'action': 'selected',
#  'piece': 'TALL, WHITE, SQUARE, WITHOUT_HOLE',
#  'piece_index': 14,
#  'attempt': 3,
#  'board': ''}
